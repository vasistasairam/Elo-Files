# %%
import pandas as pd
import glob
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
import numpy as np
# https://scikit-learn.org/stable/modules/ensemble.html#extremely-randomized-trees

# %% [markdown]
# ### Loading  Data

# %%
train_data = pd.read_csv("C:\\Kaggle competetion datasets\\Elo Merchent Category Recommendation\\Elo Feb 18th\\summary_card\\df_train_summary.csv")
test_data = pd.read_csv("C:\\Kaggle competetion datasets\\Elo Merchent Category Recommendation\\Elo Feb 18th\\summary_card\\df_test_summary.csv")

# %%
print(train_data.shape)
test_data.shape
# Out:
# (201917, 95)
# (123623, 93)

# %% [markdown]
# ### Functions to concatenate features, kfold splits

# %%
def feature_concat(train_data1,filepath):
    for file in filepath:
        data_features = pd.read_csv(file)
        train_data1=pd.merge(train_data1,data_features,how='left',on='card_id')
    return(train_data1)

# %%
def kfold_split(splitcount,train_data1,ignore_cols):  
    output_feature=['target']
    input_features=[x for x in train_data1.columns if x not in ignore_cols]
    train_X = train_data1[input_features]
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    train_X = train_X.select_dtypes(include=numerics)
    train_y = train_data1[output_feature]
    kf = StratifiedKFold(n_splits=splitcount, random_state=2018, shuffle=True)
    counter=0
    models=[]
    splits={}
    for dev_index, val_index in kf.split(train_X,train_data1['target_bin']):
        dev_X, val_X = train_X.loc[dev_index, :], train_X.loc[val_index, :]
        dev_y, val_y = train_y.loc[dev_index], train_y.loc[val_index]
        splits[counter] = [dev_X, val_X,dev_y, val_y]
        counter=counter+1
    return splits

# %% [markdown]
# ### Concatenate features

# %%
# %%time
file_list = glob.glob("C:/Kaggle competetion datasets/Elo Merchent Category Recommendation/Elo Feb 18th/features_feb21st/*.csv")
train_features = feature_concat(train_data,file_list)
# Out:
# Wall time: 17.3 s

# %%
train_features.shape
# Out:
# (201917, 166)

# %%
# train_features=train_data.copy()

# %%
# # Create correlation matrix
# corr_matrix = train_features.corr().abs()

# # Select upper triangle of correlation matrix
# upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# # Find index of feature columns with correlation greater than 0.95
# to_drop = [column for column in upper.columns if any(upper[column] > 0.80)]

# train_features=train_features1.drop(to_drop, axis=1).copy()

# %% [markdown]
# ### Binning target variable

# %%
# Binning the numeric variable to different categories
target_std=train_features['target'].std()
max_target=train_features['target'].max()+1
min_target=train_features['target'].min()-1
bins=[min_target,-3*target_std,-2*target_std,-1*target_std,target_std*1,target_std*2,target_std*3,max_target]
labels=[-4,-3,-2,0,2,3,5]
train_features['target_bin']=pd.cut(train_features['target'],bins=bins,labels=labels).astype(int)
train_features['target_bin']=train_features['target_bin'].abs()
train_features.groupby(['target_bin']).size()
# Out:
# target_bin
# 0    191093
# 2      8200
# 3       363
# 4      2237
# 5        24
# dtype: int64

# %% [markdown]
# ### KFold Splits

# %%
# %%time
kfolds = kfold_split(5,train_features,['first_active_month', 'card_id','target','target_bin','year_nunique_y','year_nunique_x', 'outliers', 'Unnamed: 0'])
# Out:
# Wall time: 2.11 s

# %% [markdown]
# ### LGBM

# %%
def run_lgb(train_X, train_y, val_X, val_y):
    param = {#'num_leaves': 30,
             'min_data_in_leaf': 177,
             'objective': 'regression',
             'max_depth': 14,
             'learning_rate': 0.01,
             "boosting": "gbdt",
#              "feature_fraction": 0.7,
             "bagging_freq": 1,
             "bagging_fraction": 0.7,
             "bagging_seed": 11,
             "metric": 'rmse',
             "lambda_l1": 0.1,
             "random_state": 133,
             "verbosity": -1}

    lgtrain = lgb.Dataset(train_X, label=train_y)
    lgval = lgb.Dataset(val_X, label=val_y)
    evals_result = {}
    model = lgb.train(param, lgtrain, 2000, valid_sets=[lgval], early_stopping_rounds=100, verbose_eval=100,
                      evals_result=evals_result)
    return model, evals_result

# %%
best_list = []
imp_list = []
for split in range(0,1):
    model, evals_result = run_lgb(kfolds[split][0], kfolds[split][2], kfolds[split][1], kfolds[split][3])
    
    best = {}
    best['best_iter'] = model.best_iteration
    best['best_score'] = model.best_score['valid_0']['rmse']
    best_list.append(best)
    feature_imp = pd.DataFrame(model.feature_importance(), kfolds[split][0].columns).sort_values(0,ascending=False).reset_index()
    feature_imp['split'] = split
    imp_list.append(feature_imp)
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's rmse: 3.70062
# [200]	valid_0's rmse: 3.66718
# [300]	valid_0's rmse: 3.65531
# [400]	valid_0's rmse: 3.64935
# [500]	valid_0's rmse: 3.64569
# [600]	valid_0's rmse: 3.64383
# [700]	valid_0's rmse: 3.64317
# [800]	valid_0's rmse: 3.64331
# Early stopping, best iteration is:
# [754]	valid_0's rmse: 3.64302

# %%
imp_list
# Out:
# [                                 index     0  split
#  0                 hist_month_diff_mean  1068      0
#  1         new_hist_purchase_amount_max   828      0
#  2            hist_authorized_flag_mean   687      0
#  3       new_hist_purchase_date_uptonow   552      0
#  4              new_hist_month_lag_mean   525      0
#  5                                 qua2   505      0
#  6                  hist_category_1_sum   458      0
#  7          new_hist_purchase_date_diff   433      0
#  8                   hist_month_nunique   401      0
#  9               hist_purchase_date_max   388      0
#  10                     cat1_trend_coef   384      0
#  11       new_hist_purchase_amount_mean   371      0
#  12           hist_purchase_amount_mean   344      0
#  13                                qua3   342      0
#  14          hist_purchase_date_uptonow   334      0
#  15        new_hist_purchase_amount_var   325      0
#  16                hist_category_1_mean   299      0
#  17            new_hist_category_1_mean   298      0
#  18              hist_new_trx_date_diff   280      0
#  19          new_hist_purchase_date_max   276      0
#  20                      hist_first_buy   270      0
#  21             hist_purchase_date_diff   268      0
#  22            hist_purchase_amount_min   252      0
#  23      new_hist_purchase_date_average   252      0
#  24                             l61-120   250      0
#  25            merc_idcount_mean_x_diff   240      0
#  26                cat1_trend_intercept   239      0
#  27              hist_purchase_date_min   236      0
#  28               hist_installments_sum   220      0
#  29           hist_category_3_mean_mean   218      0
#  ..                                 ...   ...    ...
#  130  hist_merchant_category_id_nunique    34      0
#  131          hist_subsector_id_nunique    34      0
#  132              new_hist_card_id_size    34      0
#  133        new_hist_weekofyear_nunique    32      0
#  134             new_hist_month_lag_max    29      0
#  135      new_hist_subsector_id_nunique    28      0
#  136              hist_installments_max    28      0
#  137                 hist_month_lag_min    27      0
#  138         new_hist_dayofyear_nunique    27      0
#  139          new_hist_installments_sum    25      0
#  140      new_hist_category_2_mean_mean    24      0
#  141         new_hist_dayofweek_nunique    23      0
#  142                 hist_month_lag_max    20      0
#  143              merc_idcount_<lambda>    19      0
#  144                 sub_count_<lambda>    19      0
#  145              new_hist_year_nunique    19      0
#  146          new_hist_installments_max    18      0
#  147               hist_city_id_nunique    18      0
#  148           new_hist_city_id_nunique    14      0
#  149             new_hist_month_nunique    13      0
#  150    new_hist_category_1_2_3_nunique    13      0
#  151                            max_new    12      0
#  152          new_hist_state_id_nunique    10      0
#  153             hist_dayofweek_nunique    10      0
#  154                merc_count_<lambda>     8      0
#  155                city_count_<lambda>     7      0
#  156               new_hist_weekend_sum     6      0
#  157             new_hist_month_lag_min     5      0
#  158                  hist_year_nunique     4      0
#  159                            min_new     0      0
#
#  [160 rows x 3 columns]]

# %%
imp_list_df = pd.concat(imp_list, axis=0).groupby('index').agg('mean')
imp_list_df
# Out:
#                                      0  split
# index
# card_id_total                       87      0
# city_count_<lambda>                 11      0
# city_count_mean                    166      0
# city_count_mean_x_diff             242      0
# city_count_var                     166      0
# dayofweek                           63      0
# elapsed_time                       174      0
# feature_1                          151      0
# feature_2                           93      0
# feature_3                           43      0
# hist_authorized_flag_mean          819      0
# hist_authorized_flag_sum            89      0
# hist_card_id_size                   67      0
# hist_category_1_2_3_nunique         78      0
# hist_category_1_mean               433      0
# hist_category_1_sum                668      0
# hist_category_2_mean_mean          105      0
# hist_category_3_mean_mean          340      0
# hist_city_id_nunique                62      0
# hist_dayofweek_nunique              15      0
# hist_dayofyear_nunique             168      0
# hist_first_buy                     371      0
# hist_hour_nunique                   99      0
# hist_installments_max               29      0
# hist_installments_mean             223      0
# hist_installments_min               73      0
# hist_installments_sum              332      0
# hist_installments_var              234      0
# hist_merchant_category_id_nunique  135      0
# hist_merchant_id_nunique           231      0
# ...                                ...    ...
# new_hist_purchase_amount_max       921      0
# new_hist_purchase_amount_mean      478      0
# new_hist_purchase_amount_min       270      0
# new_hist_purchase_amount_sum       199      0
# new_hist_purchase_amount_var       389      0
# new_hist_purchase_date_average     312      0
# new_hist_purchase_date_diff        509      0
# new_hist_purchase_date_max         368      0
# new_hist_purchase_date_min         292      0
# new_hist_purchase_date_uptonow     762      0
# new_hist_state_id_nunique           11      0
# new_hist_subsector_id_nunique       51      0
# new_hist_weekend_mean               74      0
# new_hist_weekend_sum                 7      0
# new_hist_weekofyear_nunique         50      0
# new_hist_year_nunique               36      0
# purchase_amount_total              175      0
# qua1                               245      0
# qua2                               760      0
# qua3                               529      0
# qua4                               299      0
# sub_count_<lambda>                  19      0
# sub_count_mean                     112      0
# sub_count_mean_x_diff              139      0
# sub_count_var                      139      0
# total_amount_<lambda>              143      0
# total_amount_mean                  131      0
# total_amount_mean_x_diff           182      0
# total_amount_var                   131      0
# weekofyear                         134      0
#
# [118 rows x 2 columns]

# %%
# %matplotlib inline 
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots(figsize=(12,10))
# lgb.plot_importance(model, max_num_features=50, height=0.8, ax=ax)
# ax.grid(False)
# plt.title("LightGBM - Feature Importance", fontsize=15)
# plt.show()

# %%
train_features1 = train_features.copy()
train_features1 = train_features1.fillna(0)

# %%
kfolds1 = kfold_split(5,train_features1,['first_active_month', 'card_id','target','target_bin','year_nunique_y','year_nunique_x', 'outliers', 'Unnamed: 0'])

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor()
from sklearn.metrics import mean_squared_error

# %%
rf_model = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=14,
           min_samples_leaf=177,
           n_estimators=100, n_jobs=-1,
           oob_score=True, random_state=133, verbose=-1)

# %%
def run_rf(train_X, train_y, val_X, val_y):

#     rftrain = lgb.Dataset(train_X, label=train_y)
#     lgval = lgb.Dataset(val_X, label=val_y)
    evals_result = {}
    model = rf_model.fit(train_X, train_y)
    y_pred = model.predict(val_X)
    rmse_score = np.sqrt(mean_squared_error(val_y, y_pred))
    return model, y_pred, rmse_score

# %%
best_list_rf = []
imp_list_rf = []
rmse_score = []
for split in range(0,1):
    model_rf, evals_result_rf, score = run_rf(kfolds1[split][0], kfolds1[split][2], kfolds1[split][1], kfolds1[split][3])
    
    best_rf = {}
    #best_rf['best_iter'] = model_rf.best_iteration
    rmse_score.append(score)
    #best_list_rf.append(best)
    feature_imp_rf = pd.DataFrame(model_rf.feature_importances_, kfolds1[split][0].columns).sort_values(0,ascending=False).reset_index()
    feature_imp_rf['split'] = split
    imp_list_rf.append(feature_imp_rf)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  8.1min finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.2s finished

# %%
feature_imp_rf.sort_values(0, ascending=False)
# Out:
#                                index         0  split
# 0               hist_month_diff_mean  0.188329      0
# 1                hist_category_1_sum  0.124626      0
# 2       new_hist_purchase_amount_var  0.081323      0
# 3            new_hist_month_lag_mean  0.064342      0
# 4                 hist_month_nunique  0.064299      0
# 5            hist_weekofyear_nunique  0.032305      0
# 6          hist_authorized_flag_mean  0.022595      0
# 7       new_hist_purchase_amount_max  0.021212      0
# 8        new_hist_purchase_date_diff  0.019960      0
# 9                    cat1_trend_coef  0.014355      0
# 10              hist_category_1_mean  0.012411      0
# 11             subsector_id_coef_new  0.011676      0
# 12          new_hist_category_1_mean  0.011339      0
# 13        new_hist_purchase_date_min  0.011157      0
# 14      new_hist_purchase_amount_sum  0.010462      0
# 15        new_hist_purchase_date_max  0.008812      0
# 16            hist_new_trx_date_diff  0.007751      0
# 17         hist_purchase_amount_mean  0.007730      0
# 18           hist_purchase_date_diff  0.007036      0
# 19                 merc_idcount_mean  0.006921      0
# 20           subsector_id_coef_inter  0.006753      0
# 21                              qua2  0.006310      0
# 22          merc_idcount_mean_x_diff  0.005994      0
# 23    new_hist_purchase_date_average  0.005967      0
# 24             purchase_amount_total  0.005866      0
# 25     new_hist_purchase_amount_mean  0.005812      0
# 26          hist_purchase_amount_sum  0.005540      0
# 27            hist_purchase_date_max  0.005454      0
# 28          hist_purchase_amount_max  0.004999      0
# 29             hist_installments_sum  0.004919      0
# ..                               ...       ...    ...
# 130            hist_state_id_nunique  0.000553      0
# 131      new_hist_weekofyear_nunique  0.000508      0
# 132         hist_authorized_flag_sum  0.000499      0
# 133             hist_city_id_nunique  0.000470      0
# 134       new_hist_dayofyear_nunique  0.000446      0
# 135       hist_purchase_date_uptonow  0.000371      0
# 136                        dayofweek  0.000347      0
# 137      hist_category_1_2_3_nunique  0.000332      0
# 138         new_hist_city_id_nunique  0.000329      0
# 139           new_hist_month_lag_max  0.000320      0
# 140                        feature_3  0.000289      0
# 141       new_hist_dayofweek_nunique  0.000277      0
# 142            merc_idcount_<lambda>  0.000268      0
# 143  new_hist_category_1_2_3_nunique  0.000236      0
# 144               hist_month_lag_max  0.000232      0
# 145          new_hist_category_1_sum  0.000215      0
# 146              merc_count_<lambda>  0.000207      0
# 147            hist_installments_min  0.000200      0
# 148                          max_new  0.000195      0
# 149               sub_count_<lambda>  0.000185      0
# 150        new_hist_state_id_nunique  0.000181      0
# 151            hist_installments_max  0.000170      0
# 152             new_hist_weekend_sum  0.000130      0
# 153           hist_dayofweek_nunique  0.000118      0
# 154            new_hist_year_nunique  0.000072      0
# 155           new_hist_month_lag_min  0.000026      0
# 156              city_count_<lambda>  0.000023      0
# 157                hist_year_nunique  0.000000      0
# 158           new_hist_month_nunique  0.000000      0
# 159                          min_new  0.000000      0
#
# [160 rows x 3 columns]

# %%
rmse_score
# Out:
# [3.663527263070328]
