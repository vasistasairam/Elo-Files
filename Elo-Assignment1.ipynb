# %%
# Load data

# %%
import pandas as pd
import numpy as np
import datetime

# %%
subset1 = pd.read_csv('C:\\Kaggle competetion datasets\\Elo Merchent Category Recommendation\\DataSubsets\\subset_1.csv')
subset1.head(5)
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_0e171c1b48       69          N             0
# 1               Y  C_ID_0e171c1b48      277          N             0
# 2               Y  C_ID_0e171c1b48      277          N             0
# 3               Y  C_ID_0e171c1b48      277          N             0
# 4               N  C_ID_0e171c1b48      277          N             0
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          A                   879  M_ID_00a6ca8a8a         -1
# 1          A                   703  M_ID_4d6321ce13         -1
# 2          A                   683  M_ID_22360595e6        -11
# 3          A                   561  M_ID_67ead1197d         -3
# 4          A                   511  M_ID_0f8e964477        -10
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# 0        -0.728876  2018-01-05 22:00:55         1.0         9            29
# ...

# %%
subset1.dtypes
# Out:
# authorized_flag          object
# card_id                  object
# city_id                   int64
# category_1               object
# installments              int64
# category_3               object
# merchant_category_id      int64
# merchant_id              object
# month_lag                 int64
# purchase_amount         float64
# purchase_date            object
# category_2              float64
# state_id                  int64
# subsector_id              int64
# dtype: object

# %%
subset1['month'] = pd.DatetimeIndex(subset1['purchase_date']).month

# %%
subset1.head()
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_0e171c1b48       69          N             0
# 1               Y  C_ID_0e171c1b48      277          N             0
# 2               Y  C_ID_0e171c1b48      277          N             0
# 3               Y  C_ID_0e171c1b48      277          N             0
# 4               N  C_ID_0e171c1b48      277          N             0
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          A                   879  M_ID_00a6ca8a8a         -1
# 1          A                   703  M_ID_4d6321ce13         -1
# 2          A                   683  M_ID_22360595e6        -11
# 3          A                   561  M_ID_67ead1197d         -3
# 4          A                   511  M_ID_0f8e964477        -10
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id  \
# 0        -0.728876  2018-01-05 22:00:55         1.0         9            29
# ...

# %%
subset1.shape
# Out:
# (3107342, 15)

# %%
data_cols = subset1.loc[:, ['card_id', 'merchant_id', 'month','merchant_category_id', 'purchase_amount']]
data_cols.head(3)
# Out:
#            card_id      merchant_id  month  merchant_category_id  \
# 0  C_ID_0e171c1b48  M_ID_00a6ca8a8a      1                   879
# 1  C_ID_0e171c1b48  M_ID_4d6321ce13      1                   703
# 2  C_ID_0e171c1b48  M_ID_22360595e6      3                   683
#
#    purchase_amount
# 0        -0.728876
# 1        -0.662759
# 2        -0.730379

# %%
# card_id, merchant_category_id, purchase_amount, purchase_date
# 1. Each customer, number of unique merchant visits per month
#    Convert visits per month to bins, and do transformation which will give count under each bin
#    cardid     0-5visits  5-10visits .....
#       1         4         3

# 2. Each customer, number of transactions per month
#    Convert number of transactions per month to bins, and do transformation which will give count under each bin
#    cardid     0-50      50-100
#       1         4         3

# %%
grup_mnth_trans = pd.DataFrame(data_cols.groupby(['card_id', 'month']).apply(lambda x: x['merchant_id'].count()))
grup_mnth_trans
# Out:
#                         0
# card_id         month
# C_ID_00007093c1 1      10
#                 2      16
#                 3      10
#                 4      14
#                 5      10
#                 6      19
#                 7      15
#                 8      17
#                 9       5
#                 10     17
#                 11      6
#                 12     12
# C_ID_0001238066 1      26
#                 2      24
#                 3      16
#                 4       9
#                 9       2
#                 10     11
#                 11     23
#                 12     37
# C_ID_0001506ef0 1       9
#                 2      11
#                 3       9
#                 5       1
#                 6       3
#                 7       2
#                 8       2
#                 9       2
#                 10      3
#                 11      7
# ...                    ..
# C_ID_1986f92f81 4       6
#                 5       2
# ...

# %%
#print(len(grup_mnth_trans.card_id.unique()))
print(grup_mnth_trans.columns)
print(grup_mnth_trans.shape)
len(data_cols.card_id.unique())
# Out:
# RangeIndex(start=0, stop=1, step=1)
# (275707, 1)
# 32379

# %%
grup_mnth_trans.head(20)
# Out:
#                         0
# card_id         month
# C_ID_00007093c1 1      10
#                 2      16
#                 3      10
#                 4      14
#                 5      10
#                 6      19
#                 7      15
#                 8      17
#                 9       5
#                 10     17
#                 11      6
#                 12     12
# C_ID_0001238066 1      26
#                 2      24
#                 3      16
#                 4       9
#                 9       2
#                 10     11
#                 11     23
#                 12     37

# %%
grup_mnth_trans.groupby('card_id').head()
# Out:
#                        merchant_id  merchant_category_id  purchase_amount
# card_id         month
# C_ID_00007093c1 1               10                    10               10
#                 2               16                    16               16
#                 3               10                    10               10
#                 4               14                    14               14
#                 5               10                    10               10
# C_ID_0001238066 1               26                    26               26
#                 2               24                    24               24
#                 3               16                    17               17
#                 4                9                     9                9
#                 9                2                     2                2
# C_ID_0001506ef0 1                9                     9                9
# ...

# %%
grup = data_cols.groupby(['card_id', 'month'])['merchant_id'].size().reset_index()
grup.head(20)
# Out:
#             card_id  month  merchant_id
# 0   C_ID_00007093c1      1           10
# 1   C_ID_00007093c1      2           16
# 2   C_ID_00007093c1      3           10
# 3   C_ID_00007093c1      4           14
# 4   C_ID_00007093c1      5           10
# 5   C_ID_00007093c1      6           19
# 6   C_ID_00007093c1      7           15
# 7   C_ID_00007093c1      8           17
# 8   C_ID_00007093c1      9            5
# 9   C_ID_00007093c1     10           17
# 10  C_ID_00007093c1     11            6
# 11  C_ID_00007093c1     12           12
# 12  C_ID_0001238066      1           26
# 13  C_ID_0001238066      2           24
# 14  C_ID_0001238066      3           17
# 15  C_ID_0001238066      4            9
# 16  C_ID_0001238066      9            2
# 17  C_ID_0001238066     10           11
# 18  C_ID_0001238066     11           23
# 19  C_ID_0001238066     12           37

# %%
grup1 = grup.groupby('card_id')
grup1.head(20)
# Out:
#                 card_id  month  merchant_id
# 0       C_ID_00007093c1      1           10
# 1       C_ID_00007093c1      2           16
# 2       C_ID_00007093c1      3           10
# 3       C_ID_00007093c1      4           14
# 4       C_ID_00007093c1      5           10
# 5       C_ID_00007093c1      6           19
# 6       C_ID_00007093c1      7           15
# 7       C_ID_00007093c1      8           17
# 8       C_ID_00007093c1      9            5
# 9       C_ID_00007093c1     10           17
# 10      C_ID_00007093c1     11            6
# 11      C_ID_00007093c1     12           12
# 12      C_ID_0001238066      1           26
# 13      C_ID_0001238066      2           24
# 14      C_ID_0001238066      3           17
# 15      C_ID_0001238066      4            9
# 16      C_ID_0001238066      9            2
# 17      C_ID_0001238066     10           11
# 18      C_ID_0001238066     11           23
# 19      C_ID_0001238066     12           37
# ...

# %%
print(len(grup.card_id.unique()))
len(grup1.card_id.unique())
# Out:
# 32379
# 32379

# %%
#### Each Customer, No Of unique merchants visits per month.

grup_card_mnth = data_cols.groupby(['card_id', 'month'])['merchant_id']
grup_card_mnth.head(20)
#grup_cust_mnth.columns = ['card_id', 'month', 'number', 'merchant_id']
# Out:
# 0          M_ID_00a6ca8a8a
# 1          M_ID_4d6321ce13
# 2          M_ID_22360595e6
# 3          M_ID_67ead1197d
# 4          M_ID_0f8e964477
# 5          M_ID_3af444944f
# 6          M_ID_e02f424f45
# 7          M_ID_c9bc3b9b09
# 8          M_ID_4175b91078
# 9          M_ID_49154b74b8
# 10         M_ID_e02f424f45
# 11         M_ID_84b69831b5
# 12         M_ID_e02f424f45
# 13         M_ID_0f8e964477
# 14         M_ID_ad5e2702ac
# 15         M_ID_9c22126564
# 16         M_ID_210cd7270f
# 17         M_ID_00a6ca8a8a
# 18         M_ID_b7337d9b18
# 19         M_ID_67ead1197d
# 20         M_ID_f3648dafbc
# 21         M_ID_c9bc3b9b09
# 22         M_ID_1b4191f84f
# 23         M_ID_2055731bce
# 24         M_ID_00a6ca8a8a
# 25         M_ID_ad5e2702ac
# 26         M_ID_fc59f8d55e
# 27         M_ID_c0ce0dd02c
# 28         M_ID_67ead1197d
# 29         M_ID_ad5e2702ac
#                 ...
# 3107312    M_ID_9139332ccc
# 3107313    M_ID_ae1697f03b
# 3107314    M_ID_c856c12632
# ...

# %%
# card_id, merchant_category_id, purchase_amount, purchase_date
# 3. month on month for each customer, number of new merchants
# Example
# customer1. Month1: 1,4,7,8       4   
# customer1. Month2: 1,4,6,9       2
# customer1. Month3: 1,4,6,10,11   2 
# customer1. Month4: 1,4,7,8       0
# customer1. Month5: 1,4,7,8       0
# 4,6,8,8,8 (cummulation,Regression)
# coeff, slope
